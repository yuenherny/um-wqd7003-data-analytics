# %% [markdown]
# ## WQD7003 - DATA ANALYTICS
# ### FINAL EXAMINATION (Part 2)
# ### ACADEMIC SESSION 2021/2022: SEMESTER 2

# %% [markdown]
# #### Student Details:
#
# #### Student Name: YU YUEN HERN
# #### Student Matric Number: S2121801

# %% [markdown]
# #### Questions Instructions:
# Lab Assessment based on Heart dataset. The dataset will be provided to the students.  You are required to write Python scripts in order to answer each of the questions. Your scripts should be written in  Jupyter notebook. The test duration is 1 hour and 15 minutes. (20 Marks)

# %% [markdown]
# #### Question 1
# Create a data frame that contains all the data from Heart.csv                            (1 Mark)

# %%
import pandas as pd

df_heart = pd.read_csv('dataset/Heart.csv')
df_heart
# Out:
#       HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                        0       1         1          1   40       1       0
# 1                        0       0         0          0   25       1       0
# 2                        0       1         1          1   28       0       0
# 3                        0       1         0          1   27       0       0
# 4                        0       1         1          1   24       0       0
# ...                    ...     ...       ...        ...  ...     ...     ...
# 4995                     0       0         0          1   29       0       0
# 4996                     0       0         0          0   24       0       0
# 4997                     0       1         0          1   24       1       0
# 4998                     0       1         1          1   33       1       0
# 4999                     0       1         1          1   35       0       0
#
#       Diabetes  PhysActivity  Age  Education  Income
# 0            0             0    9          4       3
# 1            0             1    7          6       1
# 2            0             0    9          4       8
# 3            0             1   11          3       6
# 4            0             1   11          5       4
# ...        ...           ...  ...        ...     ...
# 4995         0             1    7          6       8
# 4996         0             1    3          4       8
# 4997         0             1   13          6       7
# 4998         2             1   12          6       8
# 4999         0             0   12          4       4
#
# [5000 rows x 12 columns]

# %% [markdown]
# #### Question 2
# State the total number of smokers assuming 1-Smoker and 0-Non smoker. (2 Marks)

# %%
df_heart['Smoker'].value_counts()

print('Non smoker:', df_heart['Smoker'].value_counts().values[0])
print('Smoker:', df_heart['Smoker'].value_counts().values[1])
# Out:
# Non smoker: 2760
# Smoker: 2240

# %% [markdown]
# #### Question 3
# Normalize BMI values to a range of 0 to 1	(2 Marks)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

bmi_values = df_heart['BMI'].to_numpy()
# print(bmi_values)

bmi_values = bmi_values.reshape(-1, 1)
scaler = MinMaxScaler().fit(bmi_values)

bmi_values = scaler.transform(bmi_values)
print(bmi_values)

print('Min:', bmi_values.min())
print('Max:', bmi_values.max())
# Out:
# [[0.53061224]
#  [0.2244898 ]
#  [0.28571429]
#  ...
#  [0.20408163]
#  [0.3877551 ]
#  [0.42857143]]
# Min: 0.0
# Max: 0.9999999999999999

# %% [markdown]
# #### Question 4
# Create a line graph to view the BMI values
# (3 marks)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
df_heart['BMI'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Question 5
# Replace the following values of HeartDiseaseorAttack:
# - 0-No heart Disease
# - 1-With Heart Disease
#                        (2 Marks)

# %%
df_heart2 = df_heart.copy()
df_heart2['HeartDiseaseorAttack'] = df_heart['HeartDiseaseorAttack'].apply(lambda x: 'No heart Disease' if x == 0 else 'With Heart Disease')
df_heart2
# Out:
#      HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0        No heart Disease       1         1          1   40       1       0
# 1        No heart Disease       0         0          0   25       1       0
# 2        No heart Disease       1         1          1   28       0       0
# 3        No heart Disease       1         0          1   27       0       0
# 4        No heart Disease       1         1          1   24       0       0
# ...                   ...     ...       ...        ...  ...     ...     ...
# 4995     No heart Disease       0         0          1   29       0       0
# 4996     No heart Disease       0         0          0   24       0       0
# 4997     No heart Disease       1         0          1   24       1       0
# 4998     No heart Disease       1         1          1   33       1       0
# 4999     No heart Disease       1         1          1   35       0       0
#
#       Diabetes  PhysActivity  Age  Education  Income
# 0            0             0    9          4       3
# 1            0             1    7          6       1
# 2            0             0    9          4       8
# 3            0             1   11          3       6
# 4            0             1   11          5       4
# ...        ...           ...  ...        ...     ...
# 4995         0             1    7          6       8
# 4996         0             1    3          4       8
# 4997         0             1   13          6       7
# 4998         2             1   12          6       8
# 4999         0             0   12          4       4
#
# [5000 rows x 12 columns]

# %% [markdown]
# #### Question 6
# Do correlation analysis and perform dimensionality reduction accordingly.
# (Note: Your label is HeartDiseaseorAttack)						  (5 Marks)

# %%
import seaborn as sns

plt.figure(figsize=(20,10))
sns.heatmap(df_heart.corr(), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Remove CholCheck which contribute to slight positive correlation of 0.027
df_heart = df_heart.drop('CholCheck', axis=1)
df_heart
# Out:
#       HeartDiseaseorAttack  HighBP  HighChol  BMI  Smoker  Stroke  Diabetes  \
# 0                        0       1         1   40       1       0         0
# 1                        0       0         0   25       1       0         0
# 2                        0       1         1   28       0       0         0
# 3                        0       1         0   27       0       0         0
# 4                        0       1         1   24       0       0         0
# ...                    ...     ...       ...  ...     ...     ...       ...
# 4995                     0       0         0   29       0       0         0
# 4996                     0       0         0   24       0       0         0
# 4997                     0       1         0   24       1       0         0
# 4998                     0       1         1   33       1       0         2
# 4999                     0       1         1   35       0       0         0
#
#       PhysActivity  Age  Education  Income
# 0                0    9          4       3
# 1                1    7          6       1
# 2                0    9          4       8
# 3                1   11          3       6
# 4                1   11          5       4
# ...            ...  ...        ...     ...
# 4995             1    7          6       8
# 4996             1    3          4       8
# 4997             1   13          6       7
# 4998             1   12          6       8
# 4999             0   12          4       4
#
# [5000 rows x 11 columns]

# %% [markdown]
# #### Question 7
# You are required to create a prediction model to predict 'HeartDiseaseorAttack' based on GaussianNB model using the dataset that you have preprocessed until question 6. The training size is 80% and testing is 20%. Use split validation to validate your model.(5 marks)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# Train test split
X = df_heart.drop('HeartDiseaseorAttack', axis=1)
y = df_heart['HeartDiseaseorAttack']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=1234)

# Scaling
scaler = Normalizer()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Modelling
model = GaussianNB()
cross_validate(estimator=model, X=X_train_scaled, y=y_train)

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
print(classification_report(y_test, y_pred, target_names=['No heart disease', 'With heart disease']))
# Out:
#                     precision    recall  f1-score   support
#
#   No heart disease       0.93      0.92      0.93       895
# With heart disease       0.37      0.38      0.38       105
#
#           accuracy                           0.87      1000
#          macro avg       0.65      0.65      0.65      1000
#       weighted avg       0.87      0.87      0.87      1000

# %% [markdown]
# #### END
